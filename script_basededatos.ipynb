-- %% [markdown]
-- # [Gorca]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Gorca]    Script Date: 26/09/2024 04:57:30 p. m. ******/
CREATE DATABASE [Gorca]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Gorca', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\Gorca.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Gorca_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\Gorca_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Gorca] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Gorca].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Gorca] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Gorca] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Gorca] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Gorca] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Gorca] SET ARITHABORT OFF 
GO
ALTER DATABASE [Gorca] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Gorca] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Gorca] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Gorca] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Gorca] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Gorca] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Gorca] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Gorca] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Gorca] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Gorca] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Gorca] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Gorca] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Gorca] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Gorca] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Gorca] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Gorca] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Gorca] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Gorca] SET RECOVERY FULL 
GO
ALTER DATABASE [Gorca] SET  MULTI_USER 
GO
ALTER DATABASE [Gorca] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Gorca] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Gorca] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Gorca] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Gorca] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Gorca] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Gorca', N'ON'
GO
ALTER DATABASE [Gorca] SET QUERY_STORE = ON
GO
ALTER DATABASE [Gorca] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [memo2]

-- %%
USE [Gorca]
GO

-- %%
/****** Object:  User [memo2]    Script Date: 26/09/2024 04:57:30 p. m. ******/
CREATE USER [memo2] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [memo]

-- %%
/****** Object:  User [memo]    Script Date: 26/09/2024 04:57:30 p. m. ******/
CREATE USER [memo] FOR LOGIN [memo] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [memo2]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [memo2]
GO
ALTER ROLE [db_accessadmin] ADD MEMBER [memo2]
GO
ALTER ROLE [db_securityadmin] ADD MEMBER [memo2]
GO
ALTER ROLE [db_ddladmin] ADD MEMBER [memo2]
GO
ALTER ROLE [db_backupoperator] ADD MEMBER [memo2]
GO
ALTER ROLE [db_datareader] ADD MEMBER [memo2]
GO
ALTER ROLE [db_datawriter] ADD MEMBER [memo2]
GO
ALTER ROLE [db_denydatareader] ADD MEMBER [memo2]
GO
ALTER ROLE [db_denydatawriter] ADD MEMBER [memo2]
GO

-- %% [markdown]
-- # [dbo].[Factura]

-- %%
/****** Object:  Table [dbo].[Factura]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Factura](
	[Folio] [int] NOT NULL,
	[Version] [int] NULL,
	[Metodo_Pago] [varchar](15) NULL,
	[Num_Certif] [varchar](30) NULL,
	[Forma_Pago] [varchar](20) NULL,
	[Fecha_Emision_Fac] [date] NULL,
	[Hora_Emision_Fac] [time](7) NULL,
	[Subtotal_Fac] [money] NULL,
	[IVA_Fac] [decimal](10, 2) NULL,
	[Total_Fac] [money] NULL,
	[ID_Cli] [int] NOT NULL,
	[ID_Gorca] [int] NOT NULL,
	[Habilitado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Folio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[ID_Cli] [int] IDENTITY(1,1) NOT NULL,
	[RFC_Cli] [varchar](13) NULL,
	[Razon_Social_Cli] [varchar](80) NULL,
	[Regimen_Fiscal_Cli] [varchar](80) NULL,
	[Uso_CFDI_Cli] [varchar](30) NULL,
	[Calle_Cli] [varchar](20) NULL,
	[Numero_Cli] [int] NULL,
	[Colonia_Cli] [varchar](30) NULL,
	[Ciudad_Cli] [varchar](30) NULL,
	[CP_Cli] [varchar](6) NULL,
	[Pais_Cli] [varchar](30) NULL,
	[ID_Gorca] [int] NOT NULL,
	[Habilitado] [bit] NULL,
 CONSTRAINT [PK__Clientes__2BF99EB58078B791] PRIMARY KEY CLUSTERED 
(
	[ID_Cli] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cliente_Total]

-- %%
/****** Object:  View [dbo].[Cliente_Total]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW  [dbo].[Cliente_Total] as
(SELECT Razon_Social_Cli, SUM(Total_Fac) as Total
FROM Clientes C
INNER JOIN Factura F ON F.ID_Cli = C.ID_Cli
GROUP BY Razon_Social_Cli)
GO

-- %% [markdown]
-- # [dbo].[Categoria]

-- %%
/****** Object:  Table [dbo].[Categoria]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categoria](
	[ID_Cat] [int] NOT NULL,
	[Nombre_Cat] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Cat] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes1]

-- %%
/****** Object:  Table [dbo].[Clientes1]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes1](
	[ID_Cli] [int] IDENTITY(1,1) NOT NULL,
	[RFC_Cli] [varchar](13) NULL,
	[Razon_Social_Cli] [varchar](80) NULL,
	[Regimen_Fiscal_Cli] [varchar](80) NULL,
	[Uso_CFDI_Cli] [varchar](30) NULL,
	[Calle_Cli] [varchar](20) NULL,
	[Numero_Cli] [int] NULL,
	[Colonia_Cli] [varchar](30) NULL,
	[Ciudad_Cli] [varchar](30) NULL,
	[CP_Cli] [varchar](6) NULL,
	[Pais_Cli] [varchar](30) NULL,
	[ID_Gorca] [int] NOT NULL,
	[Habilitado] [bit] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Det_Fac]

-- %%
/****** Object:  Table [dbo].[Det_Fac]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Det_Fac](
	[Folio] [int] NOT NULL,
	[ID_Prod] [int] NOT NULL,
	[Cantidad_Fac] [int] NULL,
	[PMV_Fac] [money] NULL,
	[Importe_Fac] [money] NULL,
	[Descuento_Fac] [decimal](10, 2) NULL,
	[Habilitado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Folio] ASC,
	[ID_Prod] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Det_Tick]

-- %%
/****** Object:  Table [dbo].[Det_Tick]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Det_Tick](
	[ID_Prod] [int] NOT NULL,
	[ID_Ticket] [int] NOT NULL,
	[Cantidad_Tic] [int] NULL,
	[PMV_Tic] [money] NULL,
	[Importe_Tic] [money] NULL,
	[Descuento_Tic] [decimal](10, 2) NULL,
	[Habilitado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Ticket] ASC,
	[ID_Prod] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Empleado]

-- %%
/****** Object:  Table [dbo].[Empleado]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empleado](
	[ID_Emp] [int] IDENTITY(1,1) NOT NULL,
	[RFC_Emp] [varchar](13) NULL,
	[CURP_Emp] [varchar](18) NULL,
	[Nombre_Pila] [varchar](50) NULL,
	[Apellido_P] [varchar](20) NULL,
	[Apellido_M] [varchar](20) NULL,
	[Fecha_Nac] [date] NULL,
	[NSS] [int] NULL,
	[Puesto] [varchar](20) NULL,
	[Salario] [money] NULL,
	[Fecha_Contrato] [date] NULL,
	[Habilitado] [bit] NULL,
 CONSTRAINT [PK__Empleado__2D4D3A2344B3DDBC] PRIMARY KEY CLUSTERED 
(
	[ID_Emp] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[gorca]

-- %%
/****** Object:  Table [dbo].[gorca]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[gorca](
	[ID_Gorca] [int] NOT NULL,
	[RFC_G] [varchar](13) NULL,
	[Razon_Social_G] [varchar](80) NULL,
	[Regimen_Fiscal_G] [varchar](80) NULL,
	[Nombre_Comercial_G] [varchar](80) NULL,
	[Calle_G] [varchar](50) NULL,
	[Numero_G] [int] NULL,
	[Colonia_G] [varchar](30) NULL,
	[Ciudad_G] [varchar](20) NULL,
	[CP_G] [varchar](6) NULL,
	[Pais_G] [varchar](30) NULL,
	[Habilitado] [bit] NULL,
 CONSTRAINT [PK__gorca__6F67E063C0441C03] PRIMARY KEY CLUSTERED 
(
	[ID_Gorca] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Producto]

-- %%
/****** Object:  Table [dbo].[Producto]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Producto](
	[ID_Prod] [int] IDENTITY(1,1) NOT NULL,
	[Marca] [varchar](25) NULL,
	[Volumen] [varchar](50) NOT NULL,
	[Fecha_Max_Frescura] [date] NULL,
	[Sabor] [varchar](25) NULL,
	[SKU] [int] NULL,
	[Precio] [money] NULL,
	[Obj_Impu] [varchar](2) NULL,
	[Clave_Unidad] [varchar](10) NULL,
	[Clave_Prod_Serv] [varchar](10) NULL,
	[Base_Manual] [varchar](2) NULL,
	[Descripcion] [varchar](40) NULL,
	[Cant_Exist] [int] NULL,
	[Stock_Min] [int] NULL,
	[Stock_Max] [int] NULL,
	[ID_Prov] [int] NOT NULL,
	[ID_Cat] [int] NOT NULL,
	[Habilitado] [bit] NULL,
 CONSTRAINT [PK__Producto__B247ED708B117C58] PRIMARY KEY CLUSTERED 
(
	[ID_Prod] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Proveedores]

-- %%
/****** Object:  Table [dbo].[Proveedores]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Proveedores](
	[ID_Prov] [int] NOT NULL,
	[RFC_Prov] [varchar](13) NULL,
	[Razon_Social_Prov] [varchar](80) NULL,
	[Regimen_Fiscal_Prov] [varchar](80) NULL,
	[Nombre_Comercial_Prov] [varchar](80) NULL,
	[Calle_Prov] [varchar](50) NULL,
	[Numero_Prov] [int] NULL,
	[Colonia_Prov] [varchar](30) NULL,
	[Ciudad_Prov] [varchar](20) NULL,
	[CP_Prov] [varchar](6) NULL,
	[Pais_Prov] [varchar](30) NULL,
	[Habilitado] [bit] NULL,
 CONSTRAINT [PK__Proveedo__B247ED0280F57CCD] PRIMARY KEY CLUSTERED 
(
	[ID_Prov] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tel_Cli]

-- %%
/****** Object:  Table [dbo].[Tel_Cli]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tel_Cli](
	[ID_Cli] [int] NOT NULL,
	[Telefono] [varchar](10) NOT NULL,
	[Tipo] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Cli] ASC,
	[Telefono] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tel_Emp]

-- %%
/****** Object:  Table [dbo].[Tel_Emp]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tel_Emp](
	[ID_Emp] [int] NOT NULL,
	[Telefono] [varchar](10) NOT NULL,
	[Tipo] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Emp] ASC,
	[Telefono] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tel_Prov]

-- %%
/****** Object:  Table [dbo].[Tel_Prov]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tel_Prov](
	[ID_Prov] [int] NOT NULL,
	[Telefono] [varchar](10) NOT NULL,
	[Tipo] [varchar](20) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Prov] ASC,
	[Telefono] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ticket]

-- %%
/****** Object:  Table [dbo].[Ticket]    Script Date: 26/09/2024 04:57:30 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ticket](
	[ID_Ticket] [int] NOT NULL,
	[Fecha_Emision_Tic] [date] NULL,
	[Hora_Emision_Tic] [time](7) NULL,
	[Subtotal_Tic] [money] NULL,
	[IVA_Tic] [decimal](10, 2) NULL,
	[Total_Tic] [money] NULL,
	[ID_Emp] [int] NOT NULL,
	[ID_Gorca] [int] NOT NULL,
	[Habilitado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Ticket] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Det_Fac__Folio__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[Det_Fac]  WITH CHECK ADD FOREIGN KEY([Folio])
REFERENCES [dbo].[Factura] ([Folio])
GO

-- %% [markdown]
-- # [FK__Det_Fac__ID_Prod__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[Det_Fac]  WITH CHECK ADD  CONSTRAINT [FK__Det_Fac__ID_Prod__5CD6CB2B] FOREIGN KEY([ID_Prod])
REFERENCES [dbo].[Producto] ([ID_Prod])
GO
ALTER TABLE [dbo].[Det_Fac] CHECK CONSTRAINT [FK__Det_Fac__ID_Prod__5CD6CB2B]
GO

-- %% [markdown]
-- # [FK__Det_Tick__ID_Pro__6B24EA82]

-- %%
ALTER TABLE [dbo].[Det_Tick]  WITH CHECK ADD  CONSTRAINT [FK__Det_Tick__ID_Pro__6B24EA82] FOREIGN KEY([ID_Prod])
REFERENCES [dbo].[Producto] ([ID_Prod])
GO
ALTER TABLE [dbo].[Det_Tick] CHECK CONSTRAINT [FK__Det_Tick__ID_Pro__6B24EA82]
GO

-- %% [markdown]
-- # [FK__Det_Tick__ID_Tic__6A30C649]

-- %%
ALTER TABLE [dbo].[Det_Tick]  WITH CHECK ADD FOREIGN KEY([ID_Ticket])
REFERENCES [dbo].[Ticket] ([ID_Ticket])
GO

-- %% [markdown]
-- # [FK__Factura__ID_Cli__5441852A]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD  CONSTRAINT [FK__Factura__ID_Cli__5441852A] FOREIGN KEY([ID_Cli])
REFERENCES [dbo].[Clientes] ([ID_Cli])
GO
ALTER TABLE [dbo].[Factura] CHECK CONSTRAINT [FK__Factura__ID_Cli__5441852A]
GO

-- %% [markdown]
-- # [FK__Factura__ID_Gorc__5535A963]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD  CONSTRAINT [FK__Factura__ID_Gorc__5535A963] FOREIGN KEY([ID_Gorca])
REFERENCES [dbo].[gorca] ([ID_Gorca])
GO
ALTER TABLE [dbo].[Factura] CHECK CONSTRAINT [FK__Factura__ID_Gorc__5535A963]
GO

-- %% [markdown]
-- # [FK__Producto__ID_Cat__440B1D61]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD  CONSTRAINT [FK__Producto__ID_Cat__440B1D61] FOREIGN KEY([ID_Cat])
REFERENCES [dbo].[Categoria] ([ID_Cat])
GO
ALTER TABLE [dbo].[Producto] CHECK CONSTRAINT [FK__Producto__ID_Cat__440B1D61]
GO

-- %% [markdown]
-- # [FK__Producto__ID_Pro__4316F928]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD  CONSTRAINT [FK__Producto__ID_Pro__4316F928] FOREIGN KEY([ID_Prov])
REFERENCES [dbo].[Proveedores] ([ID_Prov])
GO
ALTER TABLE [dbo].[Producto] CHECK CONSTRAINT [FK__Producto__ID_Pro__4316F928]
GO

-- %% [markdown]
-- # [FK__Tel_Cli__ID_Cli__48CFD27E]

-- %%
ALTER TABLE [dbo].[Tel_Cli]  WITH CHECK ADD  CONSTRAINT [FK__Tel_Cli__ID_Cli__48CFD27E] FOREIGN KEY([ID_Cli])
REFERENCES [dbo].[Clientes] ([ID_Cli])
GO
ALTER TABLE [dbo].[Tel_Cli] CHECK CONSTRAINT [FK__Tel_Cli__ID_Cli__48CFD27E]
GO

-- %% [markdown]
-- # [FK__Tel_Emp__ID_Emp__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Tel_Emp]  WITH CHECK ADD  CONSTRAINT [FK__Tel_Emp__ID_Emp__4E88ABD4] FOREIGN KEY([ID_Emp])
REFERENCES [dbo].[Empleado] ([ID_Emp])
GO
ALTER TABLE [dbo].[Tel_Emp] CHECK CONSTRAINT [FK__Tel_Emp__ID_Emp__4E88ABD4]
GO

-- %% [markdown]
-- # [FK__Tel_Prov__ID_Pro__3B75D760]

-- %%
ALTER TABLE [dbo].[Tel_Prov]  WITH CHECK ADD  CONSTRAINT [FK__Tel_Prov__ID_Pro__3B75D760] FOREIGN KEY([ID_Prov])
REFERENCES [dbo].[Proveedores] ([ID_Prov])
GO
ALTER TABLE [dbo].[Tel_Prov] CHECK CONSTRAINT [FK__Tel_Prov__ID_Pro__3B75D760]
GO

-- %% [markdown]
-- # [FK__Ticket__ID_Emp__628FA481]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD  CONSTRAINT [FK__Ticket__ID_Emp__628FA481] FOREIGN KEY([ID_Emp])
REFERENCES [dbo].[Empleado] ([ID_Emp])
GO
ALTER TABLE [dbo].[Ticket] CHECK CONSTRAINT [FK__Ticket__ID_Emp__628FA481]
GO

-- %% [markdown]
-- # [FK__Ticket__ID_Gorca__6383C8BA]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD  CONSTRAINT [FK__Ticket__ID_Gorca__6383C8BA] FOREIGN KEY([ID_Gorca])
REFERENCES [dbo].[gorca] ([ID_Gorca])
GO
ALTER TABLE [dbo].[Ticket] CHECK CONSTRAINT [FK__Ticket__ID_Gorca__6383C8BA]
GO

-- %% [markdown]
-- # [CK__Det_Fac__Cantida__5812160E]

-- %%
ALTER TABLE [dbo].[Det_Fac]  WITH CHECK ADD CHECK  (([Cantidad_Fac]>(0)))
GO

-- %% [markdown]
-- # [CK__Det_Fac__Descuen__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Det_Fac]  WITH CHECK ADD CHECK  (([Descuento_Fac]>=(0)))
GO

-- %% [markdown]
-- # [CK__Det_Fac__Importe__59FA5E80]

-- %%
ALTER TABLE [dbo].[Det_Fac]  WITH CHECK ADD CHECK  (([Importe_Fac]>=(0)))
GO

-- %% [markdown]
-- # [CK__Det_Fac__PMV_Fac__59063A47]

-- %%
ALTER TABLE [dbo].[Det_Fac]  WITH CHECK ADD CHECK  (([PMV_Fac]>=(0)))
GO

-- %% [markdown]
-- # [CK__Det_Tick__Cantid__66603565]

-- %%
ALTER TABLE [dbo].[Det_Tick]  WITH CHECK ADD CHECK  (([Cantidad_Tic]>(0)))
GO

-- %% [markdown]
-- # [CK__Det_Tick__Descue__693CA210]

-- %%
ALTER TABLE [dbo].[Det_Tick]  WITH CHECK ADD CHECK  (([Descuento_Tic]>=(0)))
GO

-- %% [markdown]
-- # [CK__Det_Tick__Import__68487DD7]

-- %%
ALTER TABLE [dbo].[Det_Tick]  WITH CHECK ADD CHECK  (([Importe_Tic]>=(0)))
GO

-- %% [markdown]
-- # [CK__Det_Tick__PMV_Ti__6754599E]

-- %%
ALTER TABLE [dbo].[Det_Tick]  WITH CHECK ADD CHECK  (([PMV_Tic]>=(0)))
GO

-- %% [markdown]
-- # [Pago_Salario]

-- %%
ALTER TABLE [dbo].[Empleado]  WITH CHECK ADD  CONSTRAINT [Pago_Salario] CHECK  (([Salario]>(0)))
GO
ALTER TABLE [dbo].[Empleado] CHECK CONSTRAINT [Pago_Salario]
GO

-- %% [markdown]
-- # [CK__Factura__IVA_Fac__52593CB8]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD CHECK  (([IVA_Fac]>=(0)))
GO

-- %% [markdown]
-- # [CK__Factura__Subtota__5165187F]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD CHECK  (([Subtotal_Fac]>=(0)))
GO

-- %% [markdown]
-- # [CK__Factura__Total_F__534D60F1]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD CHECK  (([Total_Fac]>=(0)))
GO

-- %% [markdown]
-- # [CK__Producto__Precio__403A8C7D]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD  CONSTRAINT [CK__Producto__Precio__403A8C7D] CHECK  (([Precio]>=(0)))
GO
ALTER TABLE [dbo].[Producto] CHECK CONSTRAINT [CK__Producto__Precio__403A8C7D]
GO

-- %% [markdown]
-- # [CK__Producto__Stock___412EB0B6]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD  CONSTRAINT [CK__Producto__Stock___412EB0B6] CHECK  (([Stock_Min]>=(0)))
GO
ALTER TABLE [dbo].[Producto] CHECK CONSTRAINT [CK__Producto__Stock___412EB0B6]
GO

-- %% [markdown]
-- # [CK__Producto__Stock___4222D4EF]

-- %%
ALTER TABLE [dbo].[Producto]  WITH CHECK ADD  CONSTRAINT [CK__Producto__Stock___4222D4EF] CHECK  (([Stock_Max]<=(400)))
GO
ALTER TABLE [dbo].[Producto] CHECK CONSTRAINT [CK__Producto__Stock___4222D4EF]
GO

-- %% [markdown]
-- # [CK__Ticket__IVA_Tic__60A75C0F]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD CHECK  (([IVA_Tic]>=(0)))
GO

-- %% [markdown]
-- # [CK__Ticket__Subtotal__5FB337D6]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD CHECK  (([Subtotal_Tic]>=(0)))
GO

-- %% [markdown]
-- # [CK__Ticket__Total_Ti__619B8048]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD CHECK  (([Total_Tic]>=(0)))
GO

-- %% [markdown]
-- # [Gorca]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Gorca] SET  READ_WRITE 
GO
